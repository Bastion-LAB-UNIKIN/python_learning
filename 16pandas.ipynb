# %% [markdown]
# #Pandas    DATA FRAME

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
data = pd.read_excel("titanic.xlsx")

# %%
data.shape
data.columns     #voir les colonnes
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
data.head()   #vérification du chargement
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
 #on va éliminer certaine de ces colonnes en utilisant drop

# %%
data = data.drop(['sibsp', 'parch', 'ticket', 'fare', 'cabin', 'embarked','boat', 'body', 'home.dest'], axis =1)

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age
# 0  29.0000
# 1   0.9167
# 2   2.0000
# 3  30.0000
# 4  25.0000

# %%
#ANALYSE

# %%
data.describe()      #statistique des bases pour chaque colonne
# Out:
#             pclass     survived          age
# count  1309.000000  1309.000000  1046.000000
# mean      2.294882     0.381971    29.881135
# std       0.837836     0.486055    14.413500
# min       1.000000     0.000000     0.166700
# 25%       2.000000     0.000000    21.000000
# 50%       3.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
# DONNEES MANUANT

# %%
# ON VA ELIMINER LES LIGNES QUI MANQUE DES DONNEES

# %%
data = data.dropna(axis = 0)

# %%
data.shape
# Out:
# (1046, 5)

# %%
data.describe()
# Out:
#             pclass     survived          age
# count  1046.000000  1046.000000  1046.000000
# mean      2.207457     0.408222    29.881135
# std       0.841497     0.491740    14.413500
# min       1.000000     0.000000     0.166700
# 25%       1.000000     0.000000    21.000000
# 50%       2.000000     0.000000    28.000000
# 75%       3.000000     1.000000    39.000000
# max       3.000000     1.000000    80.000000

# %%
#NOMBRE DES PERSONNES PAR CLASSE

# %%
data['pclass'].value_counts()
# Out:
# pclass
# 3    501
# 1    284
# 2    261
# Name: count, dtype: int64

# %%
data['pclass'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='pclass'>

# %%
data['age'].hist()     #histogramme des âges
# Out:
# <Axes: >

# %%
#data.groupby(['sex']).mean()    #on regroupe en fonction des sexe puis en clacul la moyenne

# %%
#data.groupby(['sex', 'pclass']).mean()    #on regroupe en fonction des sexe et classe puis en clacul la moyenne

# %%
#Pandas    SERIES  =  tableau à une dimension avec indexe

# %%
#data['age']

# %%
#data = data.set_index('name')
#data['age']
