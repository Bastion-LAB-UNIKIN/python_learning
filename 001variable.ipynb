# %%
x,y=1,2.5
a=True
b="bonjour etienne"

# %%
# Arithmetique

print("Arithmetique")
print(x+y)
print(x - y)
print(x * y)
print(x / y)
print(x ** y)
# Out:
# Arithmetique
# 3.5
# -1.5
# 2.5
# 0.4
# 1.0

# %%
#comparaison

print("Comparaison")
print(x <= y)
print(x >= y)
print(x == y)
print(x != y)
# Out:
# Comparaison
# True
# False
# False
# True

# %%
#logique

print("Logique")

print(False & True)   #AND
print(False | True)   #OR
print(False ^ True)   #XOR
# Out:
# Logique
# False
# True
# True
