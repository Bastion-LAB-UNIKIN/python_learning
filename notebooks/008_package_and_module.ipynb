# %%
import math
import random
import statistics
import os
import glob

# %%
#Module Math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
print(math.cos(2*math.pi))
# Out:
# 1.0

# %%
print(math.exp(5))
# Out:
# 148.4131591025766

# %%
#Module Statistics

# %%
liste_1 = [1,6,7,9,28,99,77]

# %%
print(statistics.mean(liste_1))
# Out:
# 32.42857142857143

# %%
print(statistics.variance(liste_1))
# Out:
# 1553.2857142857142

# %%
#Module Random

# %%
random.seed(0)    #"en se fixe une séquence

# %%
#print(random.choice(liste_1))

# %%
print(random.random())  #génère un nombre float aléatoire de 0 à 1
# Out:
# 0.8444218515250481

# %%
print(random.randint(5,10))  # un entier compris entre 5 et 10
# Out:
# 8

# %%
print(random.randrange(100)) # un entier compris sur 100
# Out:
# 5

# %%
print(random.sample(range(100),10))
# Out:
# [33, 65, 62, 51, 38, 61, 45, 74, 27, 64]

# %%
print(random.sample(range(100),random.randrange(10)))
# Out:
# [36, 17]

# %%
print(random.shuffle(liste_1)) #mélange les éléments
# Out:
# None

# %%
#Module oS  operating system

# %%
os.getcwd()
# Out:
# 'c:\\Users\\Admin\\Desktop\\Bastion LAB\\python_learning'

# %%
#Module Globe

# %%
glob.glob("*")
# Out:
# ['08_package_and_module.ipynb',
#  '09_Numpy.ipynb',
#  '10_Numpyinterne.ipynb',
#  '11_statistique.ipynb',
#  '12brodkasting.ipynb',
#  '13Matplotlib.ipynb',
#  '14graphique.ipynb',
#  '15scipy.ipynb',
#  '16pandas.ipynb',
#  '16panda_serie.ipynb',
#  '17PANDASteamserries.ipynb',
#  '18_SIBORN.ipynb',
#  '19_scikitlearn.ipynb',
#  '20_Sklean.ipynb',
#  '21_Sklearn_carte.ipynb',
#  '22_Metrix.ipynb',
#  '23_PREPROCESSING.ipynb',
#  '24_Pipeline.ipynb',
#  '25_IMPUTER.ipynb',
#  '26_selection.ipynb',
#  '27_Apprentissage_non_supervse.ipynb',
#  '28_Ensemble.ipynb',
#  'bacteria.png',
#  'BTC-EUR.csv',
#  'dataset.csv',
#  'dataset.xlsx',
#  'datasets',
#  'doc01.txt',
#  'ETH-EUR.csv',
#  'fichier.txt',
#  'fichier_2.txt',
#  'figure.png',
#  'figurre.png',
#  'im.jpg',
#  'iris.csv',
#  'notebooks',
#  'PIXEL.jpeg',
#  'Preésentation 01 gith.pptx',
#  'Preésentation 02 electronique numérique & analogique.pptx',
#  'Preésentation 03 LLM & SPICE.pptx',
#  'python files',
# ...

# %%
glob.glob("*.txt")
# Out:
# ['doc01.txt', 'fichier.txt', 'fichier_2.txt']

# %%
filenames = glob.glob("*.txt")

# %%
for fille in filenames:
    with open(fille , 'r') as f:
        print(f.read())
# Out:
# mon premier push du projet
# 0^2 = 0
# 1^2 = 1
# 2^2 = 4
# 3^2 = 9
# 4^2 = 16
# 5^2 = 25
# 6^2 = 36
# 7^2 = 49
# 8^2 = 64
# 9^2 = 81
#
# lundi
# mardi
# mercredi
# jeudi
# vendredi
# samedi
# dimanche

# %%
with open('fichier.txt', 'r' ) as f :
    liste = f.read().splitlines()

liste
# Out:
# ['0^2 = 0 ',
#  '1^2 = 1 ',
#  '2^2 = 4 ',
#  '3^2 = 9 ',
#  '4^2 = 16 ',
#  '5^2 = 25 ',
#  '6^2 = 36 ',
#  '7^2 = 49 ',
#  '8^2 = 64 ',
#  '9^2 = 81 ']

# %%
liste = [line.strip() for line in open('fichier.txt' , 'r' )]
liste
# Out:
# ['0^2 = 0',
#  '1^2 = 1',
#  '2^2 = 4',
#  '3^2 = 9',
#  '4^2 = 16',
#  '5^2 = 25',
#  '6^2 = 36',
#  '7^2 = 49',
#  '8^2 = 64',
#  '9^2 = 81']
