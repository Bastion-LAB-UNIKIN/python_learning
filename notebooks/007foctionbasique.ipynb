# %% [markdown]
# fonction des bases

# %%
x = -2
abs(x)
# Out:
# 2

# %%
x = 2.12
round(x)
# Out:
# 2

# %%
liste_1 = [0,22,67,-7]

# %%
max(liste_1)
# Out:
# 67

# %%
min(liste_1)
# Out:
# -7

# %%
len(liste_1)
# Out:
# 4

# %%
sum(liste_1)
# Out:
# 82

# %%
liste_2 = [True,True,False]
all(liste_2)
# Out:
# False

# %%
any(liste_2)
# Out:
# True

# %% [markdown]
# fonction utiles

# %%
x = 10
type(x)
# Out:
# int

# %%
x = str(x)
x
type(x)
# Out:
# str

# %%
y = '20'
y= int(y)
y
# Out:
# 20

# %% [markdown]
# conversion

# %%
liste_1 = [0,61,62,65,567]

# %%
tuple(liste_1)
# Out:
# (0, 61, 62, 65, 567)

# %%
inventaire = {
    "bananes" : 5000,
    "pommes" : 2099,
    "poires" : 56898,
    "cerises" : 2892,
}

# %%
list(inventaire.keys())
# Out:
# ['bananes', 'pommes', 'poires', 'cerises']

# %%
bin(15)
# Out:
# '0b1111'

# %%
oct(15)
# Out:
# '0o17'

# %%
hex(15)
# Out:
# '0xf'

# %% [markdown]
# Imput

# %%
x = int(input('Entrez un nombre'))

# %%
type(x)
# Out:
# int

# %% [markdown]
# FORMAT()

# %%
x = 25
ville = 'Paris'
message = "la température est de {} degC à {}".format(x,ville)
print(message)
# Out:
# la température est de 25 degC à Paris

# %%
import numpy as np

# %%
parametres = {
    "w1" : np.random.randn(2, 4),
    "b1" : np.zeros((2, 1)),
    "w2" : np.random.randn(2, 2),
    "b2" : np.zeros((2, 1)),
}

# %%
for i in range(1,3):
    print("couche",i)
    print(parametres["w{}".format(i)])
# Out:
# couche 1
# [[ 1.27829766 -1.65001648 -1.04897051 -1.11583732]
#  [ 0.22017242 -1.24302304 -0.47087928  1.19475196]]
# couche 2
# [[1.03681065 0.01376721]
#  [0.57288807 1.11374647]]

# %% [markdown]
# OPEN

# %%
f = open('fichier.txt', 'w')

# %%
f.write('bonjour')
f.close()

# %%
f = open('fichier.txt' , 'r')
f.read()
f.close()

# %%
with open('fichier.txt' , 'r') as f:
    print(f.read())
# Out:
# bonjour

# %%
with open('fichier.txt' , 'w') as f:
    for i in range(10):
        f.write("{}^2 = {} \n".format(i,i**2))

# %%
with open('fichier.txt' , 'r') as f:
    print(f.read())
# Out:
# 0^2 = 0
# 1^2 = 1
# 2^2 = 4
# 3^2 = 9
# 4^2 = 16
# 5^2 = 25
# 6^2 = 36
# 7^2 = 49
# 8^2 = 64
# 9^2 = 81

# %%
V = ['BAMPIRE', 'ETIENNE', 'MALIKA', 'YASSINE', 'FATIMA']

any(V)
# Out:
# True

# %%
t = 12
i = 2
result = f'le resultat est {t}volts et {i}ampères'
