# %%
import math
import random
import statistics
import os
import glob

# %%
#Module Math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
print(math.cos(2*math.pi))
# Out:
# 1.0

# %%
print(math.exp(5))
# Out:
# 148.4131591025766

# %%
#Module Statistics

# %%
liste_1 = [1,6,7,9,28,99,77]

# %%
print(statistics.mean(liste_1))
# Out:
# 32.42857142857143

# %%
print(statistics.variance(liste_1))
# Out:
# 1553.2857142857142

# %%
#Module Random

# %%
random.seed(0)    #"en se fixe une séquence

# %%
#print(random.choice(liste_1))

# %%
print(random.random())  #génère un nombre float aléatoire de 0 à 1
# Out:
# 0.2217038962141865

# %%
print(random.randint(5,10))  # un entier compris entre 5 et 10
# Out:
# 6

# %%
print(random.randrange(100)) # un entier compris sur 100
# Out:
# 69

# %%
print(random.sample(range(100),10))
# Out:
# [57, 11, 10, 40, 65, 62, 13, 38, 70, 37]

# %%
print(random.sample(range(100),random.randrange(10)))
# Out:
# [70]

# %%
print(random.shuffle(liste_1)) #mélange les éléments
# Out:
# None

# %%
#Module oS  operating system

# %%
os.getcwd()
# Out:
# 'C:\\Users\\By Etienne\\Desktop\\etiennegit'

# %%
#Module Globe

# %%
glob.glob("*")
# Out:
# ['07_package_and_module.ipynb',
#  'fichier.txt',
#  'foctionbasique.ipynb',
#  'python-lng',
#  'Untitled.ipynb']

# %%
glob.glob("*.txt")
# Out:
# ['fichier.txt']

# %%
filenames = glob.glob("*.txt")

# %%
for fille in filenames:
    with open(fille , 'r') as f:
        print(f.read())
# Out:
# 0^2 = 0
# 1^2 = 1
# 2^2 = 4
# 3^2 = 9
# 4^2 = 16
# 5^2 = 25
# 6^2 = 36
# 7^2 = 49
# 8^2 = 64
# 9^2 = 81

# %%
with open('fichier.txt', 'r' ) as f :
    liste = f.read().splitlines()

liste
# Out:
# ['0^2 = 0 ',
#  '1^2 = 1 ',
#  '2^2 = 4 ',
#  '3^2 = 9 ',
#  '4^2 = 16 ',
#  '5^2 = 25 ',
#  '6^2 = 36 ',
#  '7^2 = 49 ',
#  '8^2 = 64 ',
#  '9^2 = 81 ']

# %%
liste = [line.strip() for line in open('fichier.txt' , 'r' )]
liste
# Out:
# ['0^2 = 0',
#  '1^2 = 1',
#  '2^2 = 4',
#  '3^2 = 9',
#  '4^2 = 16',
#  '5^2 = 25',
#  '6^2 = 36',
#  '7^2 = 49',
#  '8^2 = 64',
#  '9^2 = 81']
