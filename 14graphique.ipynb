# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()

x = iris.data
y = iris.target
names = list(iris.target_names)

print(f'x contient {x.shape[0]} exemples et {x.shape[1]} variables')
print(f'il y a {np.unique(y).size} classes')
# Out:
# x contient 150 exemples et 4 variables
# il y a 3 classes

# %% [markdown]
# (5) Graphique de Classification avec plt.scatter

# %%
plt.scatter(x[:, 0], x[:, 1] , c=y, alpha=0.5, s=x[:,2]*10)

# %% [markdown]
# (4)GRAPHIQUE 3D

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
# %matplotlib
ax = plt.axes(projection ='3d')
ax.scatter(x[:, 0], x[:, 1],x[:,2], c=y)
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %%
f = lambda x, y: np.sin(x) + np.cos(x+y)

# %%
X = np.linspace(0, 5, 100)
Y = np.linspace(0, 5, 100)
X, Y = np.meshgrid(X, Y)

Z = f(X, Y)

# %%
# %matplotlib
ax = plt.axes(projection ='3d')
ax.plot_surface(X, Y, Z, cmap='plasma')
# Out:
# Using matplotlib backend: module://matplotlib_inline.backend_inline

# %% [markdown]
# (3) HISTOGRAMME

# %%
#L histogramme donne la distribution

# %%
plt.hist(x[:, 0]) 
plt.hist(x[:, 1])  #nombre des sepale , y= nombre des fois ca apparait
# Out:
# (array([ 4.,  7., 22., 24., 37., 31., 10., 11.,  2.,  2.]),
#  array([2.  , 2.24, 2.48, 2.72, 2.96, 3.2 , 3.44, 3.68, 3.92, 4.16, 4.4 ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist2d(x[:, 0], x[:, 1])
plt.xlabel('longeur séoale')
plt.ylabel('largeur sépal')
plt.colorbar()

# %%
plt.hist2d(x[:, 0], x[:, 1], cmap ='Blues')
plt.xlabel('longeur séoale')
plt.ylabel('largeur sépal')
plt.colorbar()

# %% [markdown]
# (2) CONTOUR PLOT

# %%
#VISUALISER UN GRAPHE 3D EN VUE DE DESSUS  DANS LE CAS DES PROBLEME D OPTIMISATION

# %%
plt.contour(X, Y, Z, 20)

# %%
plt.contour(X, Y, Z, 20, colors='black')

# %%
plt.contour(X, Y, Z,20, cmap='RdGy')
plt.colorbar()

# %% [markdown]
# (1) IMSHOW  afficher des images, afficher les tableau numpuy

# %%
#matrice de corrélation

# %%
plt.imshow(np.corrcoef(Z.T), cmap='Blues')
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.imshow(np.corrcoef(x.T), cmap='Blues')
plt.colorbar()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
